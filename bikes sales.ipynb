# %%
import pandas as pd
import numpy as np

# %%
bikes = pd.read_excel('bikes.xlsx')

# %%
bikes
# Out:
#          ID Marital Status Gender  Income  Children            Education  \
# 0     12496              M      F   40000         1            Bachelors
# 1     24107              M      M   30000         3      Partial College
# 2     14177              M      M   80000         5      Partial College
# 3     24381              S      M   70000         0            Bachelors
# 4     25597              S      M   30000         0            Bachelors
# ...     ...            ...    ...     ...       ...                  ...
# 1021  16466              S      F   20000         0  Partial High School
# 1022  19273              M      F   20000         2      Partial College
# 1023  22400              M      M   10000         0      Partial College
# 1024  20942              S      F   20000         0          High School
# 1025  18484              S      M   80000         2          High School
#
#           Occupation Home Owner  Cars Commute Distance   Region  Age  \
# ...

# %%
bikes[bikes.duplicated()]
# Out:
#          ID Marital Status Gender  Income  Children            Education  \
# 1000  13507              M      F   10000         2      Partial College
# 1001  19280              M      M  120000         2      Partial College
# 1002  22173              M      F   30000         3          High School
# 1003  12697              S      F   90000         0            Bachelors
# 1004  11434              M      M  170000         5      Partial College
# 1005  25323              M      M   40000         2      Partial College
# 1006  23542              S      M   60000         1      Partial College
# 1007  20870              S      F   10000         2          High School
# 1008  23316              S      M   30000         3      Partial College
# 1009  12610              M      F   30000         1            Bachelors
# 1010  27183              S      M   40000         2      Partial College
# 1011  25940              S      M   20000         2  Partial High School
# ...

# %%
bikes=bikes.drop_duplicates()

# %%
bikes.duplicated().sum()
# Out:
# 0

# %%
bikes.shape
# Out:
# (1000, 13)

# %%
bikes['Purchased Bike'].value_counts()
# Out:
# Purchased Bike
# No     519
# Yes    481
# Name: count, dtype: int64

# %%
bikes.groupby('Gender')['Purchased Bike'].value_counts()
# Out:
# Gender  Purchased Bike
# F       No                250
#         Yes               239
# M       No                269
#         Yes               242
# Name: count, dtype: int64

# %%
bikes[bikes['Purchased Bike']=='Yes'].groupby('Gender').count()
# Out:
#          ID  Marital Status  Income  Children  Education  Occupation  \
# Gender
# F       239             239     239       239        239         239
# M       242             242     242       242        242         242
#
#         Home Owner  Cars  Commute Distance  Region  Age  Purchased Bike
# Gender
# F              239   239               239     239  239             239
# M              242   242               242     242  242             242

# %%
bikes.groupby('Occupation')['Purchased Bike'].value_counts()
# Out:
# Occupation      Purchased Bike
# Clerical        No                 89
#                 Yes                88
# Management      No                100
#                 Yes                73
# Manual          No                 64
#                 Yes                55
# Professional    Yes               150
#                 No                126
# Skilled Manual  No                140
#                 Yes               115
# Name: count, dtype: int64

# %%
bikes.groupby('Marital Status')['Purchased Bike'].value_counts()
# Out:
# Marital Status  Purchased Bike
# M               No                307
#                 Yes               231
# S               Yes               250
#                 No                212
# Name: count, dtype: int64

# %%
bikes.groupby('Commute Distance')['Purchased Bike'].value_counts()
# Out:
# Commute Distance  Purchased Bike
# 0-1 Miles         Yes               200
#                   No                166
# 1-2 Miles         No                 92
#                   Yes                77
# 10+ Miles         No                 78
#                   Yes                33
# 2-5 Miles         Yes                95
#                   No                 67
# 5-10 Miles        No                116
#                   Yes                76
# Name: count, dtype: int64

# %%
bikes.groupby(['Purchased Bike','Education'])['Income'].sum()
# Out:
# Purchased Bike  Education
# No              Bachelors               9070000
#                 Graduate Degree         5440000
#                 High School             4500000
#                 Partial College         7750000
#                 Partial High School     1720000
# Yes             Bachelors              10210000
#                 Graduate Degree         6060000
#                 High School             3960000
#                 Partial College         6750000
#                 Partial High School      900000
# Name: Income, dtype: int64

# %%
bikes.groupby(['Marital Status','Region'], as_index=False)['Purchased Bike'].value_counts()
# Out:
#    Marital Status         Region Purchased Bike  count
# 0               M         Europe             No     73
# 1               M         Europe            Yes     73
# 2               M  North America             No    190
# 3               M  North America            Yes    107
# 4               M        Pacific            Yes     51
# 5               M        Pacific             No     44
# 6               S         Europe             No     79
# 7               S         Europe            Yes     75
# 8               S  North America            Yes    113
# 9               S  North America             No     98
# 10              S        Pacific            Yes     62
# 11              S        Pacific             No     35

# %%
bikes.loc[bikes['Age']< 30,'Age_Range']='Young'

# %%
bikes
# Out:
#         ID Marital Status Gender  Income  Children        Education  \
# 0    12496              M      F   40000         1        Bachelors
# 1    24107              M      M   30000         3  Partial College
# 2    14177              M      M   80000         5  Partial College
# 3    24381              S      M   70000         0        Bachelors
# 4    25597              S      M   30000         0        Bachelors
# ..     ...            ...    ...     ...       ...              ...
# 995  23731              M      M   60000         2      High School
# 996  28672              S      M   70000         4  Graduate Degree
# 997  11809              M      M   60000         2        Bachelors
# 998  19664              S      M  100000         3        Bachelors
# 999  12121              S      M   60000         3      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# 0    Skilled Manual        Yes     0        0-1 Miles         Europe   42
# ...

# %%
bikes.loc[bikes['Age']>= 30,'Age_Range']= 'Middle_Age'

# %%
bikes
# Out:
#         ID Marital Status Gender  Income  Children        Education  \
# 0    12496              M      F   40000         1        Bachelors
# 1    24107              M      M   30000         3  Partial College
# 2    14177              M      M   80000         5  Partial College
# 3    24381              S      M   70000         0        Bachelors
# 4    25597              S      M   30000         0        Bachelors
# ..     ...            ...    ...     ...       ...              ...
# 995  23731              M      M   60000         2      High School
# 996  28672              S      M   70000         4  Graduate Degree
# 997  11809              M      M   60000         2        Bachelors
# 998  19664              S      M  100000         3        Bachelors
# 999  12121              S      M   60000         3      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# 0    Skilled Manual        Yes     0        0-1 Miles         Europe   42
# ...

# %%
bikes.loc[bikes['Age']>=60,'Age_Range']='Old'

# %%
bikes
# Out:
#         ID Marital Status Gender  Income  Children        Education  \
# 0    12496              M      F   40000         1        Bachelors
# 1    24107              M      M   30000         3  Partial College
# 2    14177              M      M   80000         5  Partial College
# 3    24381              S      M   70000         0        Bachelors
# 4    25597              S      M   30000         0        Bachelors
# ..     ...            ...    ...     ...       ...              ...
# 995  23731              M      M   60000         2      High School
# 996  28672              S      M   70000         4  Graduate Degree
# 997  11809              M      M   60000         2        Bachelors
# 998  19664              S      M  100000         3        Bachelors
# 999  12121              S      M   60000         3      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# 0    Skilled Manual        Yes     0        0-1 Miles         Europe   42
# ...

# %%
bikes.groupby('Age_Range')['Purchased Bike'].value_counts()
# Out:
# Age_Range   Purchased Bike
# Middle_Age  Yes               409
#             No                393
# Old         No                 78
#             Yes                37
# Young       No                 48
#             Yes                35
# Name: count, dtype: int64
